# %%
import math, sys, os
sys.path.append("d:/USDA-NIFA/Code")
os.chdir("d:/USDA-NIFA/Code")
os.getcwd()
# Out:
# 'e:\\Desktop\\USDA-NIFA\\Code'

# %%
target_list = list(range(7, 1799))
image_list = [f"IMG_{i:04d}_1.tif" for i in target_list]
for i in image_list:
    path = os.path.join("091425_Wallpe", "Images", i)
    if not os.path.exists(path):
        print(f"{path} is missing.")
# Out:
# 091425_Wallpe\Images\IMG_0741_1.tif is missing.
# 091425_Wallpe\Images\IMG_0742_1.tif is missing.
# 091425_Wallpe\Images\IMG_0743_1.tif is missing.
# 091425_Wallpe\Images\IMG_0744_1.tif is missing.
# 091425_Wallpe\Images\IMG_0745_1.tif is missing.
# 091425_Wallpe\Images\IMG_0746_1.tif is missing.
# 091425_Wallpe\Images\IMG_0747_1.tif is missing.
# 091425_Wallpe\Images\IMG_0748_1.tif is missing.
# 091425_Wallpe\Images\IMG_0749_1.tif is missing.
# 091425_Wallpe\Images\IMG_0750_1.tif is missing.
# 091425_Wallpe\Images\IMG_0751_1.tif is missing.
# 091425_Wallpe\Images\IMG_0752_1.tif is missing.
# 091425_Wallpe\Images\IMG_0753_1.tif is missing.
# 091425_Wallpe\Images\IMG_0754_1.tif is missing.
# 091425_Wallpe\Images\IMG_0755_1.tif is missing.
# 091425_Wallpe\Images\IMG_0756_1.tif is missing.
# 091425_Wallpe\Images\IMG_0757_1.tif is missing.
# 091425_Wallpe\Images\IMG_0758_1.tif is missing.
# 091425_Wallpe\Images\IMG_0759_1.tif is missing.
# 091425_Wallpe\Images\IMG_0760_1.tif is missing.
# ...
